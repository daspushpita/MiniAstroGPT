# %%
import os,sys
import numpy as np
import scipy as sp
import pandas as pd
import tensorflow as tf 
import matplotlib as mlt
import matplotlib.pyplot as plt
from IPython.display import HTML
from matplotlib import animation
sys.path.append("../src/mgpt/")

# %% [markdown]
# ### First download the abstracts from Arxiv and then convert it to txt files

# %%
from data_modules import ArxivDownloader, split_data_class, jason_to_txt

# %%
downloader = ArxivDownloader()
count, path = downloader.download_abstracts()
print("Returned:", count, "File:", path)
# Out:
#  201501010000 to 201502010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1200 to 1400...
# Fetching 1200-1400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201501010000+TO+201502010000%5D&start=1200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 7
#
#  201502010000 to 201503010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201502010000+TO+201503010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 141
#
#  201503010000 to 201504010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1200 to 1400...
# Fetching 1200-1400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201503010000+TO+201504010000%5D&start=1200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 72
#
#  201504010000 to 201505010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201504010000+TO+201505010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  201505010000 to 201506010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201505010000+TO+201506010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201505010000+TO+201506010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  201506010000 to 201507010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201506010000+TO+201507010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 180
#
#  201507010000 to 201508010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201507010000+TO+201508010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B201507010000+TO+201508010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B

# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1000 to 1200...
# Fetching 1000-1200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=1000&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1200 to 1400...
# Fetching 1200-1400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=1200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1400 to 1600...
# Fetching 1400-1600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=1400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1600 to 1800...
# Fetching 1600-1800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=1600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 1800 to 2000...
# Fetching 1800-2000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202503010000+TO+202504010000%5D&start=1800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 60
#
#  202504010000 to 202505010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202504010000+TO+202505010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202504010000+TO+202505010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202504010000+TO+202505010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202504010000+TO+202505010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202504010000+TO+202505010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  202505010000 to 202506010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202505010000+TO+202506010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202505010000+TO+202506010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202505010000+TO+202506010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202505010000+TO+202506010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  202506010000 to 202507010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202506010000+TO+202507010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202506010000+TO+202507010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202506010000+TO+202507010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  202507010000 to 202508010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202507010000+TO+202508010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202507010000+TO+202508010000%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202507010000+TO+202508010000%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202507010000+TO+202508010000%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202507010000+TO+202508010000%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
#
#  202508010000 to 202509010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202508010000+TO+202509010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 100
#
#  202509010000 to 202510010000
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202509010000+TO+202510010000%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 100
#
#  202510010000 to 202510172359
# Fetching results 0 to 200...
# Fetching 0-200...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202510010000+TO+202510172359%5D&start=0&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 200 to 400...
# Fetching 200-400...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202510010000+TO+202510172359%5D&start=200&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 400 to 600...
# Fetching 400-600...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202510010000+TO+202510172359%5D&start=400&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 600 to 800...
# Fetching 600-800...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202510010000+TO+202510172359%5D&start=600&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 200
# Fetching results 800 to 1000...
# Fetching 800-1000...
# URL sent: https://export.arxiv.org/api/query?search_query=%28cat%3Aastro-ph+OR+cat%3Aastro-ph.HE+OR+cat%3Aastro-ph.CO+OR+cat%3Aastro-ph.EP+OR+cat%3Aastro-ph.GA+OR+cat%3Aastro-ph.IM+OR+cat%3Aastro-ph.SR%29+AND+submittedDate%3A%5B202510010000+TO+202510172359%5D&start=800&max_results=200&sortBy=submittedDate&sortOrder=ascending
# entries on this page: 0
# No more entries.
# Downloaded 103469 abstracts to astro_abstracts_last10_years.jsonl.
# Returned: 103469 File: astro_abstracts_last10_years.jsonl

# %%
path = "/Users/pushpita/Documents/ML Projects/Building_LLM_from_scratch/MiniAstroLM/data/astro_abstracts_2025.jsonl"
split_data = split_data_class(path, split_ratio=0.1, seed=42).split_data()
print("Data split into:", split_data)
# Out:
# Train: 6175, Val: 687 saved to JSONL files
# Data split into: (                                     id  \
# 3193  http://arxiv.org/abs/2505.10487v1
# 87    http://arxiv.org/abs/2501.02052v2
# 465   http://arxiv.org/abs/2501.06298v2
# 6300  http://arxiv.org/abs/2510.03229v1
# 2031  http://arxiv.org/abs/2504.07919v3
# ...                                 ...
# 3772  http://arxiv.org/abs/2505.20669v1
# 5191  http://arxiv.org/abs/2508.02410v1
# 5226  http://arxiv.org/abs/2508.02876v1
# 5390  http://arxiv.org/abs/2509.02539v2
# 860   http://arxiv.org/abs/2502.01308v2
#
#                                                   title  \
# 3193  Boosting decision trees for Main Belt Asteroid...
# 87    Search for continuous gravitational wave signa...
# 465   Impact of memory-burdened primordial black hol...
# 6300  Robust magnetic field estimates in star-formin...
# 2031  Double White Dwarf Tides with Multi-messenger ...
# ...                                                 ...
# 3772  Mapping the Star Formation and HI Gas Properti...
# 5191  On the formation of multiple dust-trapping rin...
# 5226  The X-ray Variability and Luminosity Function ...
# 5390  Extending the Dynamical Systems Toolkit: Coupl...
# 860   In search for the Local Universe dynamical hom...
#
#                                                abstract             published  \
# 3193  One of the main bottleneck in assessing the ac...  2025-05-15T16:42:53Z
# 87    Superradiance clouds of kinetically-mixed dark...  2025-01-03T19:00:01Z
# 465   We explore the impact of the back-reaction of ...  2025-01-10T19:00:04Z
# 6300  The equipartition model is widely used to esti...  2025-10-03T17:59:03Z
# 2031  Short-period Galactic double white dwarf (DWD)...  2025-04-10T17:33:52Z
# ...                                                 ...                   ...
# 3772  We investigate the star formation and neutral ...  2025-05-27T03:36:41Z
# 5191  Isotopic properties of meteorites provide evid...  2025-08-04T13:33:15Z
# 5226  We present an analysis of $\sim$235 ks of Chan...  2025-08-04T20:11:14Z
# 5390  We study the dynamics of a two-field scalar mo...  2025-09-02T17:41:58Z
# 860   This article explores an update to the cosmogr...  2025-02-03T12:33:50Z
#
#                          categories
# 3193     [astro-ph.EP, astro-ph.IM]
# 87     [gr-qc, astro-ph.HE, hep-ph]
# 465   [hep-ph, astro-ph.CO, hep-th]
# 6300     [astro-ph.GA, astro-ph.HE]
# 2031                  [astro-ph.SR]
# ...                             ...
# 3772                  [astro-ph.GA]
# 5191                  [astro-ph.EP]
# 5226     [astro-ph.HE, astro-ph.GA]
# 5390   [hep-th, astro-ph.CO, gr-qc]
# 860                   [astro-ph.CO]
#
# [6175 rows x 5 columns],                                      id  \
# 5828  http://arxiv.org/abs/2509.07066v1
# 1670  http://arxiv.org/abs/2504.03303v1
# 3184  http://arxiv.org/abs/2505.10431v1
# 6254  http://arxiv.org/abs/2510.02821v1
# 132   http://arxiv.org/abs/2501.02610v2
# ...                                 ...
# 6732  http://arxiv.org/abs/2510.09571v1
# 1480  http://arxiv.org/abs/2504.01103v1
# 681   http://arxiv.org/abs/2501.08718v2
# 5345  http://arxiv.org/abs/2509.02019v1
# 2477  http://arxiv.org/abs/2505.01588v1
#
#                                                   title  \
# 5828  A galactic tug-of-war: how (not) to simultaneo...
# 1670  Gaia GraL: Gaia gravitational lens systems IX....
# 3184  Near-Infrared Spectroscopy of the Recurrent No...
# 6254  Band Splitting in m-Type II radio Bursts and t...
# 132   Primordial Black Hole stellar microlensing con...
# ...                                                 ...
# 6732  Deep uGMRT observations for enhanced calibrati...
# 1480  JWST reveals the diversity of nuclear obscurin...
# 681   Pixelization effects in cosmic shear angular p...
# 5345  Detection of 'super-virial' gas in the Circumg...
# 2477  SHAPE: cosmology with cluster halo intrinsic a...
#
#                                                abstract             published  \
# 5828  The satellite population of the Milky Way is s...  2025-09-08T18:00:01Z
# 1670  Aims. Quasar strong gravitational lenses are i...  2025-04-04T09:28:46Z
# 3184  Near infrared (NIR) 0.9--2.5$\mu$m spectra of ...  2025-05-15T15:51:10Z
# 6254  Type II radio bursts are signatures of shock w...  2025-10-03T08:54:27Z
# 132   Microlensing surveys of stars in the Large Mag...  2025-01-05T17:36:01Z
# ...                                                 ...                   ...
# 6732  Radio-interferometric arrays require very prec...  2025-10-10T17:23:56Z
# 1480  We investigate the capabilities of the mid-inf...  2025-04-01T18:21:20Z
# 681   We conduct a comprehensive study into the impa...  2025-01-15T10:58:59Z
# 5345  We present the first simultaneous detection of...  2025-09-02T07:06:03Z
# 2477  Galaxy clusters trace the most massive dark ma...  2025-05-02T21:13:21Z
#
#                       categories
# 5828               [astro-ph.GA]
# 1670               [astro-ph.GA]
# 3184  [astro-ph.SR, astro-ph.GA]
# 6254               [astro-ph.SR]
# 132   [astro-ph.GA, astro-ph.CO]
# ...                          ...
# 6732  [astro-ph.CO, astro-ph.IM]
# 1480               [astro-ph.GA]
# 681                [astro-ph.CO]
# 5345  [astro-ph.GA, astro-ph.HE]
# 2477  [astro-ph.CO, astro-ph.GA]
#
# [687 rows x 5 columns])

# %%
convert_data_train = jason_to_txt("train_data.jsonl", "train_data.txt").convert()
convert_data_val = jason_to_txt("val_data.jsonl", "val_data.txt").convert()
# Out:
# Loaded 6175 entries from train_data.jsonl
# Saved abstracts to train_data.txt
# Loaded 687 entries from val_data.jsonl
# Saved abstracts to val_data.txt

# %% [markdown]
# ### Loading the torch Dataset

# %%
from dataset import AstroDataset

# %%
data = AstroDataset("../data/train_data.txt", max_length=4, batch_size=3, stride=1)
my_data = data.create_dataloader(shuffle=False)

# %%
data_iter = iter(my_data)
first_batch = next(data_iter)
print("First_batch shape", np.shape(first_batch))
print("First Batch:", first_batch)
# Out:
# First_batch shape (2, 3, 4)
# First Batch: [tensor([[40720,  7890,    14, 27432],
#         [ 7890,    14, 27432,    62],
#         [   14, 27432,    62,  7890]]), tensor([[ 7890,    14, 27432,    62],
#         [   14, 27432,    62,  7890],
#         [27432,    62,  7890,    13]])]
